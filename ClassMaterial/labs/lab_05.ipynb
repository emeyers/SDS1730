# %% [raw]
# ---
# execute:
#   cache: false
# format:
#   pdf:
#     include-in-header:
#        text: |
#          \newcommand{\textasciicaret}{\^{}}
#          \usepackage{fvextra}
#          \DefineVerbatimEnvironment{Highlighting}{Verbatim}{breaklines,commandchars=\\\{\}}
#     include-before-body:
#         text: |
#          \RecustomVerbatimEnvironment{verbatim}{Verbatim}{showspaces = false, showtabs = false, breaksymbolleft={}, breaklines}
# ---

# %% [markdown]
# # Baseball Lab 5: Calculating probabilities
#
# In today's exercises, you'll get practice:
#
# 1. Using probability rules to calculate the probability of particular outcomes
# 2. Simulating Big League Baseball plays in Python
# 3. Using object-oriented programming to keep track of the state of a game
#
# Please complete this notebook by filling in the cells provided. For all problems that you must write explanations and sentences for, please provide your answer in the designated space.
#
#
# #### Deadline
#
# This assignment is due **Sunday February 22nd at 11pm**. You can turn in the assignment up to 24 hours late for 90% credit (after that, the homework will only be accepted with a Dean's Extension). Directly sharing answers is not okay, but discussing problems with the course staff or with other students is encouraged. Refer to the policies page to learn more about how to learn cooperatively. You should start early so that you have time to get help if you're stuck. If you have questions, please post them to [Ed Discussion](https://edstem.org/us/courses/89102/discussion) (and answer others' questions too).

# %% [markdown]
# # Part 0: Quote and reaction to Astroball chapter 5 (5 points)
#
# Please find an interesting quote from chapter 5 of Astroball and then write a ~one paragraph reaction to the quote below.
#
# *Quote:*  ...
#
# Reaction: ...

# %% [markdown]
# # Part 1: Calculating probabilities
#
#
# In the first set of exercises you will use the additive and multiplicative rules of probability to calculate the probability of particular outcomes.
#
# Credit: The 2nd and 3rd questions come from Teaching Statistics Using Baseball by Jim Albert.

# %% [markdown]
# ## 1.1: Big League Baseball home run probability calculations
#
# In class we will play a couple of innings of Big League Baseball. As a reminder, below are the rules of how Big League Baseball is played.
#
# 1. A Single die is rolled:
#
# - If the outcome is a 2 or 3, then the outcome is a ball
# - If the outcome is a 4 or 5, then the outcome is a strike
# - If the outcome is a 1 or 6, then the outcome is a ball in play
#
# 2. If a ball is hit in play (i.e., a 1 or 6 is rolled), we then roll two additional dice and the outcome of the play is determined by the table below:
#
# |  |  | |  | **Second Die**  |  |  |
# |:--:|:--:|:--:|:--:|:--:|:--:|:--:|
# | **First Die** |  | **1** | **2** | **3** | **4** | **5** | **6** |
# | **1** |  | Single | Out | Out | Out | Out | Error |
# | **2** |  | Out | Double | Single | Out | Single | Out |
# | **3** |  | Out | Single | Triple | Out | Out | Out |
# | **4** |  | Out | Out | Out | Out | Out | Out |
# | **5** |  | Out | Single | Out | Out | Out | Single |
# | **6** |  | Error | Out | Out | Out | Single | Home run |
#
#
#
# **Exercise 1.1 (5 points):** Please answer the following questions and put your written answers in the answer section below. Also, "show your work" by writing code to calculate your answers in the Python section below:
#
# 1. What is the probability of a strike?  I.e., what is P(strike)?
# 2. What is the probability of a ball being hit in play?  I.e., what is P(ball in play)?
# 3. What is the probability of a single being hit given that the ball is in play?  I.e., what is P(single | ball in play)?
# 4. What is the probability of a single being hit? I.e., what is P(single)?
# 5. What is the probability of a hit (i.e., a single, double, triple or home run) occurring? I.e., what is P(hit)?

# %% [markdown]
# **Answers**
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %%
# Show your work here (note: some of these results are very simple)

# %% [markdown]
# ## 1.2: Probability of scoring runs depending on the number of runners
#
# Suppose you are interested in exploring the relationship between the number of runners to reach base and the runs scored in a half-inning of baseball. For 1000 games of Big League Baseball, we record for each half-inning
#
# * Runners - the total number of runners to reach base in the half-inning
#
# * Runs - the number of runs scored.
#
# The table below classifiers 18,200 half-innings with respect to Runners and Runs
#
#
#
#  []()     | 0 Runs | 1 Run  | 2 Runs | 3 Runs | 4 Runs | 5 Runs | 6 Runs | > 6 Runs | Sum
# ------------|:------:|:------:|:------:|:------:|:------:|:------:|:------:|:--------:|:----:
# 0 Runners   |  5481  |    0   |    0   |    0   |    0   |    0   |    0   |    0     | 5481
# 1 Runner    |  5441  |   539  |    0   |    0   |    0   |    0   |    0   |    0     | 5980
# 2 Runners   |  2408  |   896  |   244  |    0   |    0   |    0   |    0   |    0     | 3548
# 3 Runners   |   463  |   778  |   434  |   108  |    0   |    0   |    0   |    0     | 1783
# 4 Runners   |   13   |   215  |   369  |   176  |    52  |    0   |    0   |    0     |  825
# 5 Runners   |   0    |    3   |    81  |   159  |    71  |   19   |    0   |    0     |  333
# 6 Runners   |   0    |    0   |    1   |    35  |    66  |   35   |   11   |    0     |  148
# 7 Runners   |   0    |    0   |    0   |    0   |    15  |   32   |   14   |    2     |   63
# 8 Runners   |   0    |    0   |    0   |    0   |    0   |    6   |   11   |    6     |   23
# 9 Runners   |   0    |    0   |    0   |    0   |    0   |    0   |    3   |    4     |    7
# 10 Runners  |   0    |    0   |    0   |    0   |    0   |    0   |    0   |    6     |    6
# 11 Runners  |   0    |    0   |    0   |    0   |    0   |    0   |    0   |    3     |    3
# Sum         | 13806  |  2431  | 1129   |   478  |   204  |   92   |   39   |    21    | 18200
#
#
#
# **Exercise 1.2 (4 points):** Please answer the following questions in the answer section, and show your work in the Python section below:
#
# 1. Estimate the probability that there are no runners on base in a particular half-inning.
#
# 2. Estimate the probability that a team doesn’t score any runs during their batting half-inning.
#
# 3. Suppose that a team has one runner on base during their half-inning – what is a probability estimate that the runner scores? I.e., estimate $P(Score ~ | ~ 1 ~ runner)$.
#
# 4. Suppose a team has three runners on base during their half-inning - what is a probability estimate that at least one run is scored? I.e., estimate $P(Score \ge 1 ~ | ~ 3 ~ runners)$.

# %% [markdown]
# **Answers:**
#
# 1.
#
# 2.
#
# 3.
#
# 4.

# %%
# Show your work in this Python cell

# %% [markdown]
# ## 1.3: Comparing real data to Big League Baseball simulations
#
# For ten consecutive games played by the Phillies in 1999, the number of runners and the number of runs scored are recorded for each half-inning. The table below classifies all half-innings by Runs and Runners.
#
#  []()     | 0 Runs | 1 Run  | 2 Runs | 3 Runs | 4 Runs | 5 Runs | 8 Runs |   Sum
# ------------|:------:|:------:|:------:|:------:|:------:|:------:|:------:|:--------:
# 0 Runners   |   57   |    0   |    0   |    0   |    0   |    0   |    0   |    57
# 1 Runner    |   46   |    5   |    0   |    0   |    0   |    0   |    0   |    51
# 2 Runners   |   17   |   12   |    5   |    0   |    0   |    0   |    0   |    34
# 3 Runners   |    3   |    5   |    9   |    0   |    0   |    0   |    0   |    17
# 4 Runners   |    0   |    1   |    6   |    1   |    0   |    0   |    0   |    8
# 5 Runners   |    0   |    0   |    1   |    1   |    0   |    2   |    0   |    5
# 6 Runners   |    0   |    0   |    0   |    1   |    1   |    1   |    0   |    2
# 7 Runners   |    0   |    0   |    0   |    0   |    0   |    0   |    0   |    1
# 10 Runners  |    0   |    0   |    0   |    0   |    1   |    0   |    1   |    1
# Sum         |   123  |   23   |   21   |    3   |    2   |    3   |    1   |    176
#
#
# **Exercise 1.3 (5 points):**  Please answer the following questions and show your work in the Python section below:
#
# 1. Compute the same probability estimates asked in parts 1-4 of the exercise 2 above.
#
# 2. Compare your answers with those of the previous exercise 2 above. Are the results from the game of Big League Baseball similar to those from real baseball?

# %% [markdown]
# **Answers**:
#
# 1.1
#
# 1.2
#
# 1.3
#
# 1.4
#
# 2.

# %%
# Show your work in this Python cell

# %% [markdown]
# # Part 2: Simulating Big League Baseball events
#
# In the next set of exercises we will write a function that generate plays that are consistent with the probability tables used in Big League Baseball.
#
#
# ## 2.1: Generating balls, strikes and in-play events
#
# Let's start by writing a function called `generate_blb_play_simple(verbose = True)` that generates outcomes consistent with rolling the first die in Big League Baseball. In particular, the function should have the following behavor:
#
# 1. It returns the word "ball" if a 2 or 3 is rolled on a simulated die
#
# 2. It returns the word "strike" if a 4 or 5 is rolled on a simulated die
#
# 3. It returns the word "in-play" if a 1 or 6 is rolled on a simulated die
#
# The function should also take an optional boolean argument called `verbose` which by default should be set to `True`. If the verbose argument is `True`, then the number rolled on the die should be printed. For example, if a 6 was rolled on the die, then the function should print the number 6, and return the string "in-play"
#
# Hints:
#
# 1. See textbook [chapter 9.1](https://www.inferentialthinking.com/chapters/09/1/Conditional_Statements.html) for how to generate simulated die rolls
#
# 2. If there are two conditions A and B, and you want to test whether either A = x or B = y, you can use the syntax: `if (A == x) or (B == y):`
#
#
# **Exercise 2.1 (7 points):** Please write the function described above. Once it is written, run it three times with the verbose flag set to `True` in order to print out the output so that we can see that it seems to be working.

# %%
import numpy as np

def generate_blb_play_simple(verbose = True): 
    
    ...

# %% [markdown]
# ## 2.2: Creating a dictionary to lookup in-play events
#
# As we discussed in class, for balls that are hit in-play, two additional die are rolled and the following table gives the outcome of the play based on the roll of the two dice:
#
#
# |[]()  |	1	| 2| 	3 | 	4	| 5	 | 6|
# |-|-|-|-|-|-|-|
# |1|	Single|	Out|	Out|	Out|	Out|	Error|
# |2|	Out|	Double|	Single|	Out|	Single|	Out|
# |3|	Out|	Single|	Triple|	Out|	Out|	Out|
# |4|	Out|	Out|	Out|	Out|	Out|	Out|
# |5|	Out|	Single|	Out|	Out|	Out|	Single|
# |6|	Error|	Out|	Out|	Out|	Single|	Home run|
#
#
# In order to be able to look up the value of a play, it will be convenient to store information from the table above into a Python dictionary. This will allow us to give the two die rolls as a "key" to the dictionary and get the value of the play as the "value" in the dictionary.
#
# Below we will create a dictionary called `play_dictionary` where the *keys* for this dictionary which will be tuples that hold the pair of dice roll values, and *values* will be strings that state the in-play event outcome.
#
# **Exercise 2.2 (6 points):** The code below has the dictionary entries for when the first die roll is a 1 and the second die roll is a 1, and for when the first die roll is a 1 and the second die roll is a 6. Please complete the dictionary for all events that are **not outs**, and test that it works by accessing and printing the values in the following cases to "show your work":
#
# 1. The first die roll is a 3 and the second die roll is a 2
#
# 2. The first die roll is a 6 and the second die roll is a 1

# %%
play_dictionary = {(1, 1) : "single", 
                   (1, 6) : "error"}

# %% [markdown]
# ## 2.3: Creating a function that displays values of in-play events
#
# Let's now create a function called `in_play_outcome(die_one, die_two)` that uses the `play_dictionary` to return the value for in-play events depending on the values of the rolls of the two dice. Because we didn't list the plays that are "outs" in our dictionary, we will first have to check whether a given pair of die rolls is a key in our `play_dictionary`. If a pair of rolls is not a key in our dictionary, we will need to return the string "out". Otherwise we will need to return the value in the dictionary.
#
# In order to return the string `"out"` if the pair of die rolls is not in the dictionary, we can use the dictionary `.get()` method. The `.get()` method takes two arguments: the key to look up in the dictionary, and a default value to return if the key is not found. For example, we can use the code
# `my_dict(key, default_value)` to look up the value for `key` in `my_dict`, and if `key` is not found, it will return `default_value`.
#
# **Exercise 2.3 (5 points):** Using the information described above, create the function `in_play_outcome(die_one, die_two)` that returns a string indicating what happened on a play based on the value of the dice. Show that it works by printing the values returned with the calls:
#
# 1. `in_play_outcome(1, 3)`
# 2. `in_play_outcome(1, 6)`
#
# Hint: remember that the keys in the `play_dictionary` are tuples!

# %%
def in_play_outcome(die_one, die_two):

    ...

# %% [markdown]
# ## 2.4: Creating the full Big League Baseball event simulation
#
# Now let's write a function called `generate_blb_play(verbose = True)` which will run a full simulation of one pitch.
#
# **Exercise 2.4 (9 points):** To start this function, copy over the function `generate_blb_play_simple` you created above, and then replaces the in-play part of the code with the code to generate a random event for when the ball is hit in-play. Once you have the function written, generate and print the verbose output of 5 calls to this function to show that it is working.
#
# Hint: For displaying the full sequence of dice rolls when the verbose flag is `True`, you can build up the string piece by piece. For example, we can combine the first die roll with the second die roll using: `str(first_roll) + ' ' + str(second_roll_die_one)`  or you can use f-strings.

# %%
def generate_blb_play(verbose = True): 
    
    ...

# %% [markdown]
# ## 2.5: Simulating a million plays and comparing the probabilities
#
# Let's now simulate a million plays of Big League Baseball and calculate the probabilities estimates of different events occurring based on the simulations results.
#
# **Exercise 2.5 (6 points):** Please write the code to simulate a million plays of Big League Baseball using the `generate_blb_play(verbose = False)` function to generate the outcomes of each pitch in the game. Store the results from all these simulated plays in a list called `outcomes`. Then calculate the proportion of outcomes that are strikes, singles and hits and save these results in variables called `strike_prob_estimate`, `single_prob_estimate` and `hit_prob_estimate` respectively. Then use the code below to print out the values stored in these variables, and in the answer section report whether these estimated probabilities calculated from these simulations are close to the theoretical probabilities you calculated in exercise 1.1 above.
#
# Hint: the following functions could be useful:
# - `my_list.append("my_string")` to add the string `"my_string"` to the end of the list `my_list`
# - `my_list.count("my_string")` to count the number of times `"my_strings"` occurs in the list `my_list`
# - `len(my_list)` will return the number of elments in the list `my_list`

# %%
# set the random seed so the same "random" game is generated each time
np.random.seed(100)


# Add your code here to run the simulations and store the results in a list called outcomes




# Calculate the estimated probabilities
strike_prob_estimate = ...
single_prob_estimate = ...
hit_prob_estimate = ...



# Print out the estimated probabilities
# You do not need to change this code, but understanding how f-strings will will be helpful for the following exercises
print(f"The probability of a strike is: {strike_prob_estimate}")
print(f"The probability of a single is: {single_prob_estimate}")
print(f"The probability of a hit is: {hit_prob_estimate}")
# Out:
# The probability of a strike is: Ellipsis
# The probability of a single is: Ellipsis
# The probability of a hit is: Ellipsis

# %% [markdown]
# **Answers**

# %% [markdown]
# # Part 3: Using object-oriented programming to keep track of the game
#
# In the exercise above, you have written a function that generates the outcome from one pitch of Big League Baseball. You can use this function to then simulate a full baseball game. However to do so you will need to keep track of the state of the game; i.e., what the score is, how many outs there are, etc. In the following exercise we will use the object-oriented programming (OOP) paradigm to do this!
#
# As discussed in class, an *object* is a collection of data, along with functions that operate on the data; the functions that are attached to an object are called *methods*. We have used several objects in this class such as pandas DataFrame objects which have methods such `my_df.mean()` and `my_data.groupby()`. We will not write our own object!
#
# For the purpose of keeping track of the state of a baseball game, the data in our object will be the state variables that define a baseball game, such as the inning, number of outs and the score. The methods that operate on this object will update the state of the game (i.e., update the number of outs, the inning, etc), based on events that happen. For example, we could write a method called `add_strike()` that adds a strike to the state of the game.
#
# In the exercises below you will create a `Baseball_Game` object which will hold the state of the game, and can be updated by calling functions (methods) on the object. We will build up this `Baseball_Game` object progressively over the course of the next few exercises. To do this, you will cut and paste parts of your code from previous exercises into new definitions of the `Baseball_Game` object, so we recommend that you carefully test each piece of code before you paste it into the next version of `Baseball_Game` object.

# %% [markdown]
# ## 3.1: Writing a constructor that can be used to create new Baseball_Game objects
#
# The features that will define the state of our baseball game are:
#
# 1. The inning
#
# 2. Whether it is the top or bottom of the inning
#
# 3. The home and visiting team scores
#
# 4. The number of outs
#
# 5. The number of balls and strikes
#
# 6. The runners that are on base
#
# 7. It will be useful to also have a flag that stores whether a game is over.
#
# For a real baseball game, we would also need to define the position in the lineup, who has been substituted out, etc, but these features are not relevant for Big League Baseball so they will not be in our `Baseball_Game` object.
#
#
# **Exercise 3.1 (6 points):**  In order to create an object that can hold the state of a game, we need to create a *constructor* method that initializes the state of the game. This initialization is done by having the object hold particular variables using the syntax `self.variable_name`. For example, to store the the fact that baseball games start in the first inning we can use the syntax `self.inning = 1`. We can then update the object by calling methods on the object once it has been constructed.
#
# A constructor in Python defined in a method that is called `__init__()`. Below is the beginning of the class definition for the `Baseball_Game` object and its constructor. Please complete the constructor by adding variables that define the state of the game and setting their values to what would be appropriate at the start of the game.

# %%
class Baseball_Game:
    
    # Constructor
    def __init__(self): 

        self.end_of_game = False
        self.inning = 1
        self.top_of_inning = True

        ...

# %% [markdown]
# ## 3.2:  Creating an object
#
# The constructor code you wrote above defines what a baseball game `Baseball_Game` object consists of. We can think of this code like a [cookie cutter](https://en.wikipedia.org/wiki/Cookie_cutter). Every time you want a new `Baseball_Game` object, you can use this constructor code to create the actual instance of `Baseball_Game` object that can store the state of a baseball game. In this way, the constructor code is like a cookie cutter that can be used to create new cookies. When you use the code to create a new object, it is like using the cookie cutter to cut out a new cookie from the dough (i.e., each time you use the code, it will create a new object that has the same properties).
#
# Let's call the constructor method to create a new baseball game object (i.e., let's call our cookie cutter to create a new cookie). We can do this using the code: `my_game = Baseball_Game()`.
#
# **Exercise 3.2 (3 points):** Try creating a new `Baseball_Game` object below and print it. The printed results are not yet very useful, right?
#
# You can also access the stored variables in the object using the syntax `object_name.variable_name`. For example, we can access the current inning using `my_game.inning`. Try to also print whether it is the top of the inning.

# %% [markdown]
# ## 3.3:  Writing a method to print the state of the game
#
# In order to make this object useful, we will need a way to print the actual state of the game. The method `__str__()` is a "magic" method that is used to return a character string representation of the object. This `__str__()` magic method is called by Python every time the `print()` function is called on the object.
#
# **Exercise 3.3 (8 points):** The code below starts to define the `__str__` method. Right now it prints the inning number and whether it is the top or the bottom of the inning. Please try to complete this method by printing the full state of the baseball game. In particular, at the start of the game, this method should print out:
#
# `Top of the 1st`
# `0 outs, 0 balls, and 0 strikes`
# `Bases empty`
# `Away score: 0   Home score: 0`
#
# Hint: Build up this string piece by piece (as you did in exercise 2.4). Using f-strings (as shown below) could also be a good idea. Additionally, if you include a `"\n"` in your string this will add a new line to the string to put the different components of the state of the game on different lines.

# %%
class Baseball_Game:
    
    # Constructor
    def __init__(self): 

        self.inning = 1
        self.top_of_inning = True
        
        # fill this in with the rest of the code you wrote in exercise 3.1   


    # returns a string to print the game state
    def __str__(self):
        
        if self.top_of_inning:
            top_bottom_inning_name = "Top"
        else:
            top_bottom_inning_name = "Bottom"

        if self.inning == 1:
            inning_suffix = "st"
        elif self.inning == 2:
            inning_suffix = "nd"
        elif self.inning == 3:
            inning_suffix = "rd"
        else:
            inning_suffix = "th"
        
        inning_string = f"{top_bottom_inning_name} of the {self.inning}{inning_suffix}\n"
            
        
        # add code that builds a complete string that specifies the full state of the game

        outs_ball_strings = ...
        
        
        game_state_string = inning_string  + "\n"    # + outs_ball_strings + "\n"  +  ...
        

        return game_state_string
        






# create an instance of the object and print it to test if the __str__ method is working correctly

my_game = Baseball_Game()

print(my_game)
# Out:
# Top of the 1st

# %% [markdown]
# ## 3.4: Adding runs to the game
#
# Let's now begin to create methods that will update the state of the game. Let's start with the `add_runs(self, num_runs = 1):` which will add runs to the team that is batting. The code below shows where this method should be added.
#
# **Exercise 3.4 (6 points):** Please complete the code below with all the relevant `Baseball_Game` code you have written so far.

# %%
class Baseball_Game:
    
    # Constructor
    def __init__(self): 

        self.inning = 1
        self.top_of_inning = True
        
        # Fill this in from your previous work...
        


    # returns a string to print the game state
    def __str__(self):
        
        # Fill this in from your previous work...
        game_state_string = ""
        
        return game_state_string

        
    # method to add runs to the state of the game
    def add_runs(self, num_runs = 1):

        ...
        # Fill in your new code here


        

# Testing code by creating an instance of the object and printing it to test if the add_runs() method is working correctly
my_game = Baseball_Game()
my_game.add_runs()
print(my_game)

# %% [markdown]
# ## 3.5: Adding more methods that update the state of the game
#
# Let's now complete the object by adding the following methods:
#
# 1. `update_half_inning(self):` If it is currently the top of the inning, this method should make it the bottom of the inning. If it is the bottom of the inning, this method should make it the top of the inning and increase the inning count. The method should also reset ball, strikes, base runners, etc. Finally, it should check to see if the game has ended and update the  `end_of_game` flag if the game has ended.
#
#
# 2. `add_outs(self, num_outs = 1):` Should add outs to the current state of the game. It should then check if the outs are greater than 2, and if so it should call the `update_half_inning(self):` method.
#
#
# 3. `add_runner_on_first(self):` Should add a runner on first and advance other runners one base. It should update the score if a run has scored.
#
#
# 4. `add_strike(self):` and `add_ball(self):` Should add balls and strikes. If a walk has occured it should add a runner on first. If three strikes have occured it should call the `add_outs` method.
#
#
# 5. `add_single(self)`: This should add a single. All base runners advance by one base.
#
#
# 6. `add_double(self):`, This should add a double. All base runners advance by two bases.
#
#
# 7. `add_triple(self):` and `add_home_run(self):` This should add a triple or home run. All runners on base should score with these events.
#
#
# **Exercise 3.5 (15 points):** Please add all the methods described above.  Once you have created the full `Baseball_Game` object you can use the add the special method `%%writefile baseball_game.py` which will write the object to a file called `baseball_game.py`. We can then load this object as a module and use it in part 4.

# %%
#%%writefile baseball_game.py


# Cut and paste your previous version of the Baseball_Game object here and then fill in the remaining methods

# Once you are done uncomment the top line so that you create a file called baseball_game.py

# %% [markdown]
# # Part 4: Running complete game simulations
#
# Now that we have the `Baseball_Game` object that stores the state of the game, and the `generate_blb_play()` function, we can run a full simulation of a baseball game!

# %% [markdown]
# ## 4.1: Running a simulation of a game
#
# To run the full simulation we will use a `while loop` that will run until the end of the baseball game is reached (i.e., `my_game.end_of_game = True`). Inside the loop we will do the following:
#
# 1. Use the `generate_blb_play(verbose = False)` function to generate a play and store it in the name `curr_event`
#
# 2. Append the event string that was generated to the `all_events` list to have a record of all the events that were generated
#
# 3. Use a series of if/elif statements to update the Baseball_Game object with each type of event that could occur by calling the appropriate method on the `Baseball_Game` object.
#
# **Exercise 4.1 (10 points):** The code begins begins the process for you. Please complete it to run a full game. After the game is over, print all the events that occurred in the game and the final state (i.e., the score).

# %%
# set the random seed so the same "random" game is generated each time
np.random.seed(1000)

import baseball_game as game

my_game = game.Baseball_Game()

all_events = []


while (not my_game.end_of_game):

    # generate a random event and save it to a variable curr_event

    # add the event in a list called all_events

    # update the Baseball_Game object based on the event that was generated using if elif statements
    

    # delete this break statement once your code is written
    break



# print out the list of all events that occurred in the game and also the final state of the game

# %% [markdown]
# ## 4.2: Computing simulated probabilities
#
# Let's now calculate the proportion of times that events occurred in our simulated game.
#
#
# **Exercise 4.2 (5 points):** Please answer the following questions and show your work in the code section below:
#
# 1. What is the observed proportion of strikes that occurred?
#
# 2. What is the observed proportion of singles that occurred?
#
# 3. What is the observed proportion of hits that occurred?

# %% [markdown]
# **Answers**
#
# 1.
#
# 2.
#
# 3.

# %%
# Show your work here...

# %% [markdown]
# # 5. Reflection (3 points)
#
# Please fill out the lab 5 reflection on Canvas to let us know how this lab, and the class overall, is going for you.

# %% [markdown]
# # 6.  Submitting your work
#
# Once you're finished filling in and running all cells, you should submit your assignment as a pdf on Gradescope. You can access Gradescope through Canvas on the left-side of the class home page. The problems in each lab assignment are numbered. When submitting on Gradescope, please **make sure to select the correct pages of your pdf that correspond to each problem**. Failure to mark pages correctly **will result in points being deducted** from your score.
#
# To convert this Jupyter notebook document to a pdf please run the code in the cell below. This should produce a pdf document which should appear in the files tab on the left (you might need to refresh the files tab to see this file). You can then right click on this file (command click on a mac), to download this pdf document which you can upload to Gradescope.
#
# Please be sure to check that all the code and output are visible before submitting your pdf to Gradescope as **points will be deducted for missing code and output that is not visible** since we will not be able to grade this.

# %%
# %%capture

# !quarto render lab_05.ipynb --cache-refresh --to pdf

# %% [markdown]
# #### Alternative submission instructions
#
# If converting your Jupyter notebook to a pdf using the command in the cell above does not work, an alternative way to convert your Jupyter notebook is:
#
# 1.  Go to "File" at the top-left of your Jupyter Notebook
# 2.  Under "Download as" (or "Save and Export Notebook As...") and select "HTML (.html)"
# 3.  After the .html has downloaded, open it and then select "File" and "Print" (note you will not actually be printing)
# 4.  From the print window, select the option to save as a .pdf
